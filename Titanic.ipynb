# %% [markdown]
# ## TITANIC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/lourdesrodriguez/Documents/MasterDATASCIENCE/20191129_MasterDATASCIENCE/20200120_EjerciciosLRM/Titanic

# %%
# Objetivos
    # Identificar correlaciones entre la variable 'Survived' y el resto de variables

# %%
# Lectura de datos 

dfTitanic = pd.read_csv("train.csv")
dfTitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Conocer los datos
dfTitanic.shape
# Out:
# (891, 12)

# %%
dfTitanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dfTitanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dfTitanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dfTitanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dfTitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Interpretación de la estadística inicial:
    # Solo sobrevivió el 38% de los pasajeros.
    # La media de edad se sitúa en en 30 años.
    # El 50% de las personas que viajaban iban acompañadas (Hermano/a, Esposo/a).
    # Solo un 38% tenía padres o hijos a bordo.
    # El precio del billete llegó a alcanzar 512$.

# %%
# Distribución categórica y valores únicos

dfTitanic.describe(include=['O'])
# Out:
#                                 Name   Sex  Ticket    Cabin Embarked
# count                            891   891     891      204      889
# unique                           891     2     681      147        3
# top     Walker, Mr. William Anderson  male  347082  B96 B98        S
# freq                               1   577       7        4      644

# %%
# Limpieza de datos
    # Abrimos el DF sólo con las columnas de interés descartando las columnas que no tienen valor
    
dfTitanic = pd.read_csv("train.csv", usecols=['PassengerId','Survived', 'Pclass',
                                              'Sex', 'Age','SibSp','Parch','Fare','Embarked'])
dfTitanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
dfTitanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
# Eliminamos las filas nulas, sin esos valores en la edad no tienen sentido parte del análisis

dfTitanic.dropna(inplace=True)

# %%
dfTitanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
dfTitanic.shape
# Out:
# (712, 9)

# %%
# Plan de Acción
    # 1. Agrupar por Clase
    # 2. Agrupar por Sexo
    # 3. Agrupar por Edad
    # 4. Agrupar por Clase, Sexo, Edad
    # 5. Relación Supervivientes con los Parientes
    # 6. Relación Supervivientes con el Puerto de embarque
    # 7. Relación Supervivientes con el Precio Billete

# %%
# 1. Agrupación por Clase

dfTitanic.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.652174
# 2    0.479769
# 3    0.239437
# Name: Survived, dtype: float64

# %%
dfTitanic.pivot_table('Survived',
                      index=['Pclass'],
                      aggfunc=np.sum,
                     margins=True)
# Out:
#         Survived
# Pclass
# 1            120
# 2             83
# 3             85
# All          288

# %%
# 2. Agrupación por Sexo
